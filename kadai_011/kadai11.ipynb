# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# 配列arrayの要素を順番に出力
for planet in array:
  print (planet)

i = 0

# 変数iの値が9になるまで値を出力
while i != 9:

  #変数arrayの値を出力
  print(array[i])

  i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
